# %% [markdown]
# # Candidate Ranking System - Colab Sandbox
#
# This sandbox demonstrates the candidate ranking engine developed by **2+** for the Redrob Hackathon. It runs the hybrid dense-sparse candidate ranking pipeline on a sample set of candidate profiles.

# %% [markdown]
# ### 1. Clone the repository

# %%
# !git clone https://github.com/anmolraj499-ai/Candidate-Ranking.git
# %cd Candidate-Ranking

# %% [markdown]
# ### 2. Install dependencies
# Installing `numpy`, `sentence-transformers`, `python-docx`, `torch`, `gradio`, and `pandas` as specified in `requirements.txt`.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### 3. Run the ranking pipeline
# We run the ranker offline using local model weights against the `sample_candidates.json` file.

# %%
# Note: We run on sample_candidates.json here. For the full run, candidates.jsonl is used.
# !python rank.py --candidates ./sample_candidates.json --out ./sample_output.csv

# %% [markdown]
# ### 4. Display the top ranked candidates

# %%
import pandas as pd
df = pd.read_csv("sample_output.csv")
print(f"Total ranked candidates: {len(df)}")
pd.set_option('display.max_colwidth', None)
df.head(10)
